# %% [markdown]
# #Mission 1
# 1. Sign Language Dataset을 받는다.
# 2. Sequential을 통해 적당한 아키텍처를 작성한다.
# 3. 5개 이상의 Image Augmentation을 포함시킨다.
# 4. Regularization 방법을 적용한다.
# 5. Validation Accuracy Score를 높여보자!
#
# Optimizer, Loss, Metric에 주의!

# %% [markdown]
# # Hint!
#
# 1. flow_from_directory X -> flow
# 2. sigmoid -> softmax
# 3. BinaryCrossEntropy -> categorical_crossentropy

# %%
# https://www.kaggle.com/datamunge/sign-language-mnist/download

# %%
# !git clone https://github.com/narfian/sign_MNIST_Data
# Out:
# Cloning into 'sign_MNIST_Data'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 1), reused 10 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.

# %%
import numpy as np
import pandas as pd
import os

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Dropout
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
DATA_PATH = 'sign_MNIST_Data/data'
train_df=pd.read_csv(os.path.join(DATA_PATH, 'sign_mnist_train.csv'))
test_df=pd.read_csv(os.path.join(DATA_PATH, 'sign_mnist_test.csv'))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 164.4 MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7172 entries, 0 to 7171
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 43.0 MB

# %%
train_df.describe()
# Out:
#               label        pixel1  ...      pixel783      pixel784
# count  27455.000000  27455.000000  ...  27455.000000  27455.000000
# mean      12.318813    145.419377  ...    161.137898    159.824731
# std        7.287552     41.358555  ...     63.610415     64.396846
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        6.000000    121.000000  ...    128.000000    125.500000
# 50%       13.000000    150.000000  ...    182.000000    182.000000
# 75%       19.000000    174.000000  ...    204.000000    204.000000
# max       24.000000    255.000000  ...    255.000000    255.000000
#
# [8 rows x 785 columns]

# %%
train_df.head(6)
# Out:
#    label  pixel1  pixel2  pixel3  ...  pixel781  pixel782  pixel783  pixel784
# 0      3     107     118     127  ...       206       204       203       202
# 1      6     155     157     156  ...       175       103       135       149
# 2      2     187     188     188  ...       198       195       194       195
# 3      2     211     211     212  ...       225       222       229       163
# 4     13     164     167     170  ...       157       163       164       179
# 5     16     161     168     172  ...        48       238       255       255
#
# [6 rows x 785 columns]

# %%
train_label=train_df['label']
train_label.head()
trainset=train_df.drop(['label'],axis=1)
trainset.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  ...  pixel781  pixel782  pixel783  pixel784
# 0     107     118     127     134  ...       206       204       203       202
# 1     155     157     156     156  ...       175       103       135       149
# 2     187     188     188     187  ...       198       195       194       195
# 3     211     211     212     212  ...       225       222       229       163
# 4     164     167     170     172  ...       157       163       164       179
#
# [5 rows x 784 columns]

# %%
X_train = trainset.values
X_train = trainset.values.reshape(-1,28,28,1)
print(X_train.shape)
# Out:
# (27455, 28, 28, 1)

# %%
test_label=test_df['label']
X_test=test_df.drop(['label'],axis=1)
print(X_test.shape)
X_test.head()
# Out:
# (7172, 784)
#    pixel1  pixel2  pixel3  pixel4  ...  pixel781  pixel782  pixel783  pixel784
# 0     149     149     150     150  ...       106       112       120       107
# 1     126     128     131     132  ...       184       184       182       180
# 2      85      88      92      96  ...       226       225       224       222
# 3     203     205     207     206  ...       230       240       253       255
# 4     188     191     193     195  ...        49        46        46        53
#
# [5 rows x 784 columns]

# %%
from sklearn.preprocessing import LabelBinarizer
lb=LabelBinarizer()
y_train=lb.fit_transform(train_label)
y_test=lb.fit_transform(test_label)

# %%
X_test=X_test.values.reshape(-1,28,28,1)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (27455, 28, 28, 1) (27455, 24) (7172, 28, 28, 1) (7172, 24)

# %%
# train_datagen = ImageDataGenerator(rescale = 1./255)

# X_test=X_test/255

# %%
# fig,axe=plt.subplots(2,2)
# fig.suptitle('Preview of dataset')
# axe[0,0].imshow(X_train[0].reshape(28,28),cmap='gray')
# axe[0,0].set_title('label: 3  letter: C')
# axe[0,1].imshow(X_train[1].reshape(28,28),cmap='gray')
# axe[0,1].set_title('label: 6  letter: F')
# axe[1,0].imshow(X_train[2].reshape(28,28),cmap='gray')
# axe[1,0].set_title('label: 2  letter: B')
# axe[1,1].imshow(X_train[4].reshape(28,28),cmap='gray')
# axe[1,1].set_title('label: 13  letter: M')

# %%
# sns.countplot(train_label)
# plt.title("Frequency of each label")

# %%
EPOCH = 50
BATCH_SIZE = 200

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                  rotation_range = 0,
                                  height_shift_range=0.2,
                                  width_shift_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

valid_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_gen = train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
valid_gen = valid_datagen.flow(X_test, y_test, batch_size=BATCH_SIZE)

# %%
model=Sequential([
                  Conv2D(128, 5, 1, padding='same', activation='relu', input_shape=(28,28,1)),
                  MaxPool2D(3, 2, padding='same'),
                  Conv2D(64, 2, 1, padding='same', activation='relu'),
                  MaxPool2D(2, 2, padding='same'),
                  Conv2D(32, 2, 1, padding='same', activation='relu'),
                  MaxPool2D(2, 2, padding='same'),
                  Flatten(),
                  Dense(512, activation='relu'),
                  Dropout(0.5),
                  Dense(24, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 28, 28, 128)       3328
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        32832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          8224
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# ...

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_gen,
         epochs = EPOCH,
          validation_data=valid_gen
         )
# Out:
# Epoch 1/50
# 138/138 [==============================] - 7s 52ms/step - loss: 3.0529 - accuracy: 0.0903 - val_loss: 2.5521 - val_accuracy: 0.2383
# Epoch 2/50
# 138/138 [==============================] - 7s 51ms/step - loss: 2.4157 - accuracy: 0.2411 - val_loss: 1.5202 - val_accuracy: 0.5701
# Epoch 3/50
# 138/138 [==============================] - 7s 51ms/step - loss: 1.8277 - accuracy: 0.3970 - val_loss: 1.2210 - val_accuracy: 0.6074
# Epoch 4/50
# 138/138 [==============================] - 7s 51ms/step - loss: 1.4711 - accuracy: 0.5088 - val_loss: 0.9530 - val_accuracy: 0.6725
# Epoch 5/50
# 138/138 [==============================] - 7s 51ms/step - loss: 1.2390 - accuracy: 0.5855 - val_loss: 0.7687 - val_accuracy: 0.7298
# Epoch 6/50
# 138/138 [==============================] - 7s 51ms/step - loss: 1.0877 - accuracy: 0.6303 - val_loss: 0.5536 - val_accuracy: 0.8161
# Epoch 7/50
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# epochs_range = range(epochs)
epochs_range = range(EPOCH)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
